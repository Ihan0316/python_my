# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

data=np.random.rand(50)
print(type(data))
print(data)

seri=pd.Series(data)
print(type(seri))
print(seri)

seri.plot()

matplotlib.style.use('ggplot')
# Out:
# <class 'numpy.ndarray'>
# [0.80111522 0.20152516 0.00534529 0.62393459 0.32440486 0.32133596
#  0.8319972  0.93332225 0.92651969 0.64755643 0.06368457 0.88498741
#  0.23921948 0.89652407 0.33206673 0.31085665 0.7629743  0.0135245
#  0.93434316 0.16395749 0.7882944  0.83542001 0.83159124 0.14196778
#  0.67526045 0.62441456 0.37607133 0.97642174 0.09497524 0.22876476
#  0.39441955 0.39468066 0.12482197 0.31564898 0.34290857 0.59702461
#  0.00748848 0.70410115 0.10726806 0.87873601 0.88139697 0.60695211
#  0.89574476 0.21466767 0.07776166 0.18020008 0.33674146 0.35410184
#  0.19060816 0.24840925]
# <class 'pandas.core.series.Series'>
# 0     0.801115
# 1     0.201525
# 2     0.005345
# 3     0.623935
# 4     0.324405
# 5     0.321336
# 6     0.831997
# 7     0.933322
# 8     0.926520
# 9     0.647556
# 10    0.063685
# 11    0.884987
# 12    0.239219
# 13    0.896524
# 14    0.332067
# 15    0.310857
# 16    0.762974
# 17    0.013525
# 18    0.934343
# 19    0.163957
# 20    0.788294
# ...
